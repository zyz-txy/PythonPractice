# %%
import matplotlib.pyplot as plt
import random

#展示中文
plt.rcParams['font.sans-serif'] = ['SimHei']

x = [i for i in range(1,25)]
y_bj = [ random.randint(10,15) for i in x]
y_xa = [ random.randint(13,18) for i in x]

#在plot之前创建画布
plt.figure(figsize = (10,5)) #设置画布大小，宽，高
plt.plot(x,y_bj,label='北京') #折线图 -->如果没有画布，会自动创建画布
plt.plot(x,y_xa,label='西安')

#设置折线图详细信息
plt.title("气温变化折线图",fontsize = 15) #标题
plt.xlabel("时间") #x轴
plt.ylabel("温度") #y轴

plt.xticks(x[1::2]) #x轴刻度
plt.yticks(y) #y轴刻度
plt.grid(linestyle = '--',alpha = 0.5) #显示网格样式，深浅
plt.legend(loc = 'upper left') #显示图例


plt.show() #显示图表
