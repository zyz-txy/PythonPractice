# %%
import pandas as pd

#构造DataFram -- 创建数据集（学员成绩信息）
df = pd.DataFrame([
    {"姓名":"张三","语文":80,"数学":90,"英语":75}
    ,{"姓名":"李四","语文":75,"数学":85,"英语":90}
    ,{"姓名":"王五","语文":90,"数学":80,"英语":85}
    ,{"姓名":"赵六","语文":85,"数学":75,"英语":90}
    ,{"姓名":"孙七","语文":95,"数学":85,"英语":80}
    ,{"姓名":"周八","语文":80,"数学":90,"英语":75}
    ,{"姓名":"吴九","语文":70,"数学":80,"英语":90}
    ,{"姓名":"郑十","语文":60,"数学":70,"英语":80}
])
#统计计算
print(f"语文最高分{df['语文'].max()}，最低分{df['语文'].min()}，平均分{df['语文'].mean():.2f}")
print(f"数学最高分{df['数学'].max()}，最低分{df['数学'].min()}，平均分{df['数学'].mean():.2f}")
print(f"英语最高分{df['英语'].max()}，最低分{df['英语'].min()}，平均分{df['英语'].mean():.2f}")
#type(df['语文'])
# Out:
# 语文最高分95，最低分60，平均分79.38
# 数学最高分90，最低分70，平均分81.88
# 英语最高分90，最低分75，平均分83.12
