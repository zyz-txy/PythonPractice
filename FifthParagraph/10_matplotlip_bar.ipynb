# %%
import matplotlib.pyplot as plt

#展示中文
plt.rcParams['font.sans-serif'] = ['SimHei']#设置中文为黑体

#创建子图
plt.subplots(nrows=1,ncols=2,figsize=(20,6),dpi=100) #nrows代表行,ncols代表列
# Out:
# (<Figure size 2000x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))
